# %%
import pandas as pd

df1 = pd.read_csv('tips.csv')
df1.columns = ['總票價', '小費', '吸煙者', '日期', '時間', '大小']
df1['小費比例'] = df1['小費'] / df1['總票價']

# %%
def top(df, n=5,column='小費比例'):
    return df.sort_values(by=column,ascending=False).iloc[:n]

top(df1)
# Out:
#        總票價    小費  吸煙者   日期      時間  大小      小費比例
# 172   7.25  5.15  Yes  Sun  Dinner   2  0.710345
# 178   9.60  4.00  Yes  Sun  Dinner   2  0.416667
# 67    3.07  1.00  Yes  Sat  Dinner   1  0.325733
# 232  11.61  3.39   No  Sat  Dinner   2  0.291990
# 183  23.17  6.50  Yes  Sun  Dinner   4  0.280535

# %%
list(df1.groupby('吸煙者'))
# Out:
# [('No',
#          總票價    小費 吸煙者    日期      時間  大小      小費比例
#   0    16.99  1.01  No   Sun  Dinner   2  0.059447
#   1    10.34  1.66  No   Sun  Dinner   3  0.160542
#   2    21.01  3.50  No   Sun  Dinner   3  0.166587
#   3    23.68  3.31  No   Sun  Dinner   2  0.139780
#   4    24.59  3.61  No   Sun  Dinner   4  0.146808
#   ..     ...   ...  ..   ...     ...  ..       ...
#   235  10.07  1.25  No   Sat  Dinner   2  0.124131
#   238  35.83  4.67  No   Sat  Dinner   3  0.130338
#   239  29.03  5.92  No   Sat  Dinner   3  0.203927
#   242  17.82  1.75  No   Sat  Dinner   2  0.098204
#   243  18.78  3.00  No  Thur  Dinner   2  0.159744
#
#   [151 rows x 7 columns]),
#  ('Yes',
#          總票價    小費  吸煙者   日期      時間  大小      小費比例
#   56   38.01  3.00  Yes  Sat  Dinner   4  0.078927
#   58   11.24  1.76  Yes  Sat  Dinner   2  0.156584
#   60   20.29  3.21  Yes  Sat  Dinner   2  0.158206
#   61   13.81  2.00  Yes  Sat  Dinner   2  0.144823
#   62   11.02  1.98  Yes  Sat  Dinner   2  0.179673
#   ..     ...   ...  ...  ...     ...  ..       ...
#   234  15.53  3.00  Yes  Sat  Dinner   2  0.193175
#   236  12.60  1.00  Yes  Sat  Dinner   2  0.079365
#   237  32.83  1.17  Yes  Sat  Dinner   2  0.035638
#   240  27.18  2.00  Yes  Sat  Dinner   2  0.073584
#   241  22.67  2.00  Yes  Sat  Dinner   2  0.088222
#
#   [93 rows x 7 columns])]

# %%
df1.groupby('吸煙者').apply(top)
# Out:
# /tmp/ipykernel_57933/2704321095.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df1.groupby('吸煙者').apply(top)
#            總票價    小費  吸煙者    日期      時間  大小      小費比例
# 吸煙者
# No  232  11.61  3.39   No   Sat  Dinner   2  0.291990
#     149   7.51  2.00   No  Thur   Lunch   2  0.266312
#     51   10.29  2.60   No   Sun  Dinner   2  0.252672
#     185  20.69  5.00   No   Sun  Dinner   5  0.241663
#     88   24.71  5.85   No  Thur   Lunch   2  0.236746
# Yes 172   7.25  5.15  Yes   Sun  Dinner   2  0.710345
#     178   9.60  4.00  Yes   Sun  Dinner   2  0.416667
#     67    3.07  1.00  Yes   Sat  Dinner   1  0.325733
#     183  23.17  6.50  Yes   Sun  Dinner   4  0.280535
#     109  14.31  4.00  Yes   Sat  Dinner   2  0.279525

# %%
import numpy as np
frame = pd.DataFrame({'data1':np.random.randn(1000),
                      'data2':np.random.randn(1000)})
frame
# Out:
#         data1     data2
# 0    0.121578  0.382655
# 1    0.861143  1.095448
# 2    0.306197 -0.246994
# 3   -0.131868  2.464204
# 4    1.543651 -0.009311
# ..        ...       ...
# 995 -1.655112 -1.234096
# 996  0.467774 -1.001561
# 997 -0.360446 -1.190001
# 998  0.125820  1.012514
# 999  0.699944  0.288197
#
# [1000 rows x 2 columns]

# %%
quartiles = pd.cut(frame.data1,4)

# %%
list(frame.data2.groupby(quartiles))
# Out:
# /tmp/ipykernel_57933/2900926345.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   list(frame.data2.groupby(quartiles))
# [(Interval(-2.766, -1.398, closed='right'),
#   45    -0.796836
#   50     0.531065
#   55    -0.402170
#   86    -0.618839
#   87    -0.189166
#            ...
#   961   -0.479885
#   963    2.054553
#   972   -0.329373
#   985   -1.895532
#   995   -1.234096
#   Name: data2, Length: 81, dtype: float64),
#  (Interval(-1.398, -0.035, closed='right'),
#   3      2.464204
#   7     -0.876766
#   9      0.171920
#   10     0.531501
#   11    -0.420075
#            ...
#   987   -1.124336
#   988    1.062932
#   990   -0.766588
#   992    2.136624
#   997   -1.190001
#   Name: data2, Length: 399, dtype: float64),
#  (Interval(-0.035, 1.328, closed='right'),
#   0      0.382655
#   1      1.095448
#   2     -0.246994
#   5     -1.840373
#   6      1.194551
#            ...
#   993   -1.962081
#   994   -0.695371
#   996   -1.001561
#   998    1.012514
#   999    0.288197
#   Name: data2, Length: 424, dtype: float64),
#  (Interval(1.328, 2.691, closed='right'),
#   4     -0.009311
#   29    -2.290991
#   34    -0.245652
#   39     0.646576
#   42     0.180227
#            ...
#   952   -0.232474
#   957   -0.912081
#   960    0.547628
#   968    0.255368
#   975    1.369129
#   Name: data2, Length: 96, dtype: float64)]
